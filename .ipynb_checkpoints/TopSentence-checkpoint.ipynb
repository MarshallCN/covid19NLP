# %%
import pandas as pd
import pickle
from tqdm import tqdm

# %%
with open('./data_combined/daily_news_balanced.pickle', 'rb') as handle:
    daily_news_balanced = pickle.load(handle)

# %%
with open('sort_weighted_23.pickle', 'rb') as handle:
    sort_weighted_23 = pickle.load(handle)

# %%
with open('sort_weighted_24.pickle', 'rb') as handle:
    sort_weighted_24 = pickle.load(handle)

# %%
with open('sort_weighted_25.pickle', 'rb') as handle:
    sort_weighted_25 = pickle.load(handle)

# %%
# 距离Topic 1 最近的3个news, 值越大【0,1】离这个话题越近
sort_weighted_23[1].sort_values(ascending=False).head(3)
# Out:
# 336049    0.932049
# 107259     0.92689
# 143831    0.920742
# Name: 1, dtype: object

# %%
sort_weighted_23
# Out:
#           1         2    3         4         5         6    7          8  \
# 0       NaN       NaN  NaN       NaN  0.217351       NaN  NaN        NaN
# 1       NaN       NaN  NaN       NaN       NaN   0.73163  NaN        NaN
# 2       NaN       NaN  NaN       NaN       NaN       NaN  NaN        NaN
# 3       NaN  0.273613  NaN  0.597256       NaN       NaN  NaN        NaN
# 4       NaN       NaN  NaN       NaN       NaN       NaN  NaN        NaN
# ...     ...       ...  ...       ...       ...       ...  ...        ...
# 388426  NaN       NaN  NaN       NaN       NaN       NaN  NaN        NaN
# 388427  NaN       NaN  NaN       NaN   0.32788       NaN  NaN        NaN
# 388428  NaN       NaN  NaN  0.586135       NaN  0.301051  NaN        NaN
# 388429  NaN       NaN  NaN       NaN       NaN       NaN  NaN        NaN
# 388430  NaN       NaN  NaN       NaN       NaN   0.84264  NaN  0.0364631
#
#                9        10   11        12        13         14   15        16  \
# ...

# %%
for topic in range(1,21):
    print("Topic:",topic)
    for text in daily_news_balanced[23].iloc[list(sort_weighted_23[topic].sort_values(ascending=False).head(3).index),0]:
        print(text)
# Out:
# Topic: 1
# ['difficult', 'time', 'shall', 'pass', 'view', 'post', 'instagram', 'steadfast', 'amazing', 'mothers', 'glue', 'family', 'happy', 'happy', 'day']
# ['using', 'social', 'media', 'recommended', 'share', 'things', 'caution', 'prevent', 'spread', 'fake', 'news', 'amidst', 'coronavirus', 'pandemic']
# ['weeknd', 'releases', 'new', 'music', 'video', 'eyes', 'hits', 'march', 'pm', 'weeknd', 'letting', 'coronavirus', 'stop', 'releasing', 'bangers']
# Topic: 2
# ['amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'amp', 'nbsp']
# ...

# %%
for topic in range(1,21):
    print("Topic:",topic)
    for text in daily_news_balanced[24].iloc[list(sort_weighted_24[topic].sort_values(ascending=False).head(3).index),0]:
        print(text)
# Out:
# Topic: 1
# ['doctor', 'actress', 'sophia', 'myles', 'dad', 'peter', 'also', 'died', 'following', 'short', 'fight', 'killer', 'virus']
# ['behalf', 'everyone', 'ics', 'thank', 'like', 'share', 'thanks', 'workers', 'share', 'message', 'story', 'social', 'media', 'via', 'applauseforit']
# ['find', 'us', 'favorite', 'podcast', 'app', 'listen', 'full', 'episode', 'want', 'hear']
# Topic: 2
# ['even', 'social', 'distance', 'need', 'spiritual', 'god', 'make', 'greatest', 'good', 'come', 'forth', 'greatest', 'evil', 'death', 'son', 'well', 'would', 'not', 'god', 'able', 'willing', 'make', 'good', 'come', 'even', 'lives', 'end', 'lost', 'added']
# ['wan', 'na', 'see', 'closed', 'take', 'problem', 'away', 'trying', 'part', 'make', 'sure', 'everybody', 'stays', 'safe', 'home', 'try', 'contain', 'thing', 'much', 'possible']
# ...

# %%
for topic in range(1,21):
    print("Topic:",topic)
    for text in daily_news_balanced[25].iloc[list(sort_weighted_25[topic].sort_values(ascending=False).head(3).index),0]:
        print(text)
# Out:
# Topic: 1
# ['world', 'share', 'spread', 'word', 'song', 'produced', 'dawiebeatz', 'perfect', 'way', 'start', 'new', 'week', 'amidst', 'ongoing', 'corona', 'virus']
# ['lady', 'gaga', 'via', 'instagram', 'gaga', 'admitted', 'many', 'fun', 'things', 'planned', 'celebrate', 'release', 'album']
# ['leaders', 'repeated', 'common', 'theme', 'asking', 'residents', 'live', 'lives', 'check', 'neighbors', 'practice', 'common', 'sense', 'maintain', 'social', 'distancing']
# Topic: 2
# ['pray', 'virus', 'come', 'end', 'things', 'go', 'back', 'normal', 'let', 'no', 'deaths', 'not', 'infections', 'speak', 'healthy', 'world', 'call', 'apon', 'jehovah', 'protect', 'world', 'cover', 'us', 'blood', 'jesus', 'sinners', 'please', 'forgive', 'us']
# ['love', 'neighbor', 'faith', 'requires', 'go', 'world', 'share', 'gifts', 'known', 'faith', 'jesus', 'said', 'let', 'light', 'shine', 'men', 'may', 'see', 'good', 'works', 'glorify', 'father', 'heaven', 'matthew']
# ...
